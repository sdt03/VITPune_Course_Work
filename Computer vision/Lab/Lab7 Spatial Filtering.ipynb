# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r"/Users/shoumikdaterao/Desktop/TY Sem 5/Comp vision/Images//Classic.jpg")
img = cv2.resize(img, (250,200))
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

kernel = np.array([[-1/9, -1/9, -1/9],
                       [-1/9, 8/9, -1/9],
                       [-1/9, -1/9, -1/9]])


    # another kernal without 1/9
out = cv2.filter2D(img, ddepth=-1, kernel=kernel)


plt.imshow(img, 'gray')
plt.title("OG image gray")
plt.show()

plt.imshow(out, 'gray')
plt.title('high pass filter')
plt.show()

# %%
img = cv2.imread(r"/Users/shoumikdaterao/Desktop/TY Sem 5/Comp vision/Images//Classic.jpg")
img = cv2.resize(img, (250,200))
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

kernel = np.ones([3, 3])
kernel = kernel / 9

out1 = cv2.filter2D(img, ddepth=-1, kernel=kernel)


plt.imshow(img, 'gray')
plt.title("OG image gray")
plt.show()

plt.imshow(out1, 'gray')
plt.title('LPF')
plt.show()

# %%
def low_pass_average(path):

    kernel = np.ones([3, 3], dtype = int)
    kernel = kernel / 9

    out1 = cv2.filter2D(src=image, ddepth=-1, kernel=kernel)

    out2 = cv2.blur(src=image, ksize=(3,3))  # 5x5, 7x7, 11x11

    plt.imshow(image, 'gray')
    plt.title('Input Image')
    plt.show()

    plt.imshow(out1, 'gray')
    plt.title('Low Pass Average Filter')
    plt.show()

    plt.imshow(out2, 'gray')
    plt.title('Low Pass Average Filter - In built function')
    plt.show()

# %%
def low_pass_median(path):

    out = cv2.medianBlur(src=image, ksize = 3)  # 5, 7, 9, 11

    plt.imshow(image, 'gray')
    plt.title('Input Image')
    plt.show()

    plt.imshow(out, 'gray')
    plt.title('Low Pass Median Filter')
    plt.show()

# %%
def high_pass(path):

    kernel = np.array([[-1/9, -1/9, -1/9],
                       [-1/9, 8/9, -1/9],
                       [-1/9, -1/9, -1/9]])


    # another kernal without 1/9
    out = cv2.filter2D(src=image, ddepth=-1, kernel=kernel)

    plt.imshow(image, 'gray')
    plt.title('Input Image')
    plt.show()

    plt.imshow(out, 'gray')
    plt.title('High Pass Filter')
    plt.show()

# %%
def high_boost(path):

    kernel = np.ones([3, 3], dtype = int)
    kernel = kernel / 9

    blur_image = cv2.filter2D(src=image, ddepth=-1, kernel=kernel)

    out = cv2.addWeighted(image, 2, blur_image, -1, 0) #



    plt.imshow(image, 'gray')
    plt.title('Input Image')
    plt.show()

    plt.imshow(out, 'gray')
    plt.title('High Boost Filter')
    plt.show()

# %%
image = cv2.imread(r"/Users/shoumikdaterao/Desktop/TY Sem 5/Comp vision/Images//Classic.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
x,y = gray.shape[:2]

plt.imshow(gray,'gray')
plt.title('Original Image')
plt.show()


low_pass_average(gray)

low_pass_median(gray)

high_pass(gray)

high_boost(gray)
