# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# AND

# %%
path = input("Enter the image path ")
img1 = cv2.imread(path,1)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

path = input("Enter the image path ")
img2 = cv2.imread(path,1)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

print(img1.shape)
print(img2.shape)

width = 20
height = 20
dim = (width, height)

imgR1 = cv2.resize(img1, dim)
imgR2 = cv2.resize(img2, dim)

AND = cv2.bitwise_and(imgR1, imgR2)

plt.imshow(imgR1, cmap='gray')
plt.show()
print(imgR1)

plt.imshow(imgR2, cmap='gray')
plt.show()
print(imgR2)

plt.imshow(AND, cmap='gray')
plt.show()
print(AND)
# Out:
# Enter the image path R8.jpg
# Enter the image path P.jpeg
# (8064, 6048)
# (509, 640)
# [[106 129  29  16 151  23  27  25  29  31  34  42  49  50  51 102 121 114
#    69 161]
#  [188 156   4  31 151  25  23  14  18  20  22  25  32  38  62  54  68  90
#   101 101]
#  [199 187  40  79 151  87  73  32  32  37  26  18  21  61 175  39  49  39
#    47  58]
#  [145 145 220  38 154  11  54  12  19  12  57  55  42  14 178 115  97  73
#    92  34]
#  [212 222 236   6 154 112  58  28   9  54  45  65  66  78 100 210 229 237
#   105  50]
#  [141 230 233  31 138  48  94  82  21  13  11  67 213  13  40  50  32  95
#    94  54]
#  [221 165 147  54 115  66 112  41  74  49  74  48  40 213 223 226 231 236
#   159 225]
#  [224 230 230  47  77 113 152 172  25   7 171 153  57  91 192 203 215 220
#   223 227]
#  [225 216 233  23  57  45  43  14   1  17 186 206 124  97  91   3 200 222
#   198 219]
#  [226 208 203 100  79   1  95  94  97  92  46  18   5  67  96  42  22  14
#     8  85]
#  [209 227 223 145 131  88  28  14  18  33  49  79  99 153 173 187 157 133
#   147 112]
#  [175 203 186  77 126 115 174 155 166 182 177 191 180 182 186 178 175 199
#   157 150]
#  [145  85 138 139 121  87 136 128 180 121 162 203 136 121 203 145 115 112
#   165 183]
#  [133 109 252 205 205 136 168 189 133 104 212 179 135 168 219 252 139 136
#   132 182]
#  [166 201 182 176 180 149 206 152 172 180 242 206 232 159 206 186 146 117
#   101 170]
#  [230 182 148 153 155 135 180 202 138 186 197 167 189  76 190 203 111 189
#   142 192]
#  [195 176 177 126 122 175 247 194 173 132 149 163 155 203 121 145 163 171
#   152 185]
#  [165 172 163 178 165 162 182 173 143 207 176 165 162  84 105 137 152 192
#   146 215]
#  [174 162 168 167 153 158 201 175 182 210 185 160 138 138 158 133 173 155
#   160 165]
#  [160 162 168 179 164 130 143 164 126 178 145 119 133 189 199 172 160 154
#   143 119]]
# [[ 31 236 190 227  21 138 106  61 122 181  85  34  47 176  85 181 227 134
#    92 211]
#  [ 14 223  74 212 248 246 241 244 213 193 121  43 178 233  35 170  68  26
#   154 220]
#  [ 36 166  20 210 220 246  83 123 247  80 116 215  39 108  51 202 107  28
#   126 148]
#  [158  32 118  78 119 136 201 208 226 221  29  94 181  12  90 129  42 185
#    69 203]
#  [232 215 238 135 131  46 110 214  27 157  84 131 216  60   9  58  19 202
#    52 116]
#  [201 111 166 162 175 181 137 167 164 141  61  87  92  36 111 117  95   7
#    69  60]
#  [ 96 169  80 168  38 192 186 181  56  78 163 116 235  98 208  30 127  10
#    78  77]
#  [ 30  67  68  28 133 226  97  93  74  47  86 161 111 233   9   1   1   6
#    70  63]
#  [ 60  69  16  45  97 124  81 143 148  29  44  22 215  44  32  82  12 126
#   166 155]
#  [ 21  92  28 205 248 245 172 113  25  10 142 196  45  29  62  80  87  72
#    73 213]
#  [ 84  43  55  23  77  32 235 154 152 102  49   7 113  74  15  11 107  16
#   114  38]
#  [ 18 137  18  62  50 150  41 143 141  91  36  36  26 111  30  45 101 202
#   198  83]
#  [ 36  29  29  20  43 192 128 138  86  82  40  11  58  83   7  49 118 142
#    31  11]
#  [  3  33   3 206 162 193 195 127 115 151  49  10  17  87  19  56  79   6
#    36 126]
#  [ 54  51 161  16  61 115  99 122  45  40  66   2  45 241  62  29  53  31
#   117  48]
#  [ 18   1   8 170 170 177 138 174  51  11  81  12  67 210   4  49 253 158
#   207 238]
#  [ 42  42 111 129  76  93  99 134 190 188 121   4 103  97 115  71 179  39
#    15  22]
#  [136  10 161 134 104  75 114 103 185  74  68 209  59  72  54  57  38   1
#     4 166]
#  [136 137  89 156 193 102 104 112 131  83 162 171 156 115  90  59  61  54
#   127  46]
#  [170 105 145  37 153 221 149 114  90 121 106 148 118 109  75 135 104  53
#    89  69]]
# [[ 10 128  28   0  21   2  10  25  24  21   0  34  33  48  17  36  97   2
#    68 129]
#  [ 12 156   0  20 144  16  17   4  16   0  16   9  32  32  34  34  68  26
#     0  68]
#  [  4 162   0  66 148  86  65  32  32   0  16  18   5  44  35   2  33   4
#    46  16]
#  [144   0  84   6  18   8   0   0   2  12  25  22  32  12  18   1  32   9
#    68   2]
#  [192 214 236   6 130  32  42  20   9  20   4   1  64  12   0  18   1 200
#    32  48]
#  [137 102 160   2 138  48   8   2   4  13   9  67  84   4  40  48   0   7
#    68  52]
#  [ 64 161  16  32  34  64  48  33   8   0   2  48  40  64 208   2 103   8
#    14  65]
#  [  0  66  68  12   5  96   0  12   8   7   2 129  41  73   0   1   1   4
#    70  35]
#  [ 32  64   0   5  33  44   1  14   0  17  40   6  84  32   0   2   8  94
#   134 155]
#  [  0  80   8  68  72   1  12  80   1   8  14   0   5   1  32   0  22   8
#     8  85]
#  [ 80  35  23  17   1   0   8  10  16  32  49   7  97   8  13  11   9   0
#    18  32]
#  [  2 137  18  12  50  18  40 139 132  18  32  36  16  38  26  32  37 194
#   132  18]
#  [  0  21   8   0  41  64 128 128  20  80  32  11   8  81   3  17 114   0
#     5   3]
#  [  1  33   0 204 128 128 128  61   1   0  16   2   1   0  19  56  11   0
#     4  54]
#  [ 38   1 160  16  52  17  66  24  44  32  66   2  40 145  14  24  16  21
#   101  32]
#  [  2   0   0 136 138 129 128 138   2  10  65   4   1  64   4   1 109 156
#   142 192]
#  [  2  32  33   0  72  13  99 130 172 132  17   0   3  65 113   1 163  35
#     8  16]
#  [128   8 161 130  32   2  50  37 137  74   0 129  34  64  32   9   0   0
#     0 134]
#  [136 128   8 132 129   6  72  32 130  82 160 160 136   2  26   1  45  18
#    32  36]
#  [160  32 128  33 128 128 133  32  90  48   0  20   4  45  67 132  32  16
#     9  69]]

# %%
img1 = cv2.imread(r"R8.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2 = cv2.imread(r"P.jpeg")
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
print(img1.shape)
print(img2.shape)

# resixe 10 x10
width = 10
height = 10 
dim = (width, height)
  
# resize image
imgR1 = cv2.resize(img1, dim)
imgR2 = cv2.resize(img2, dim)

OR = cv2.bitwise_or(imgR1, imgR2)

plt.imshow(imgR1, cmap='gray')
plt.show()
print(imgR1)
plt.imshow(imgR2, cmap='gray')
plt.show()
print(imgR2)
plt.imshow(OR, cmap='gray')
plt.show()
print(OR)
# Out:
# (8064, 6048)
# (509, 640)
# [[159   8  24  19  22  32  43  45 108 107]
#  [190  33  90  28  31  22  64  47  24 112]
#  [235  60   7 133  55  35 224  22  83 245]
#  [188  21  69 107 152 163 213 213 224 231]
#  [155 232  55 115  65 119 222   2  25 177]
#  [196 209 148 113 157 175 169 178 162 168]
#  [126 176 185 142 182 232 238 130 103 234]
#  [201 175 188 180 159 126 179 172 180 201]
#  [154 183 186 103 151 173 138 177 172 159]
#  [165 166 166 147 186 200 179 161 157 157]]
# [[148 230 201  97 237  59 158 165  19 197]
#  [131 135 130 245 229 228  58 149  12 183]
#  [107 230 242 108  46  30  20  35   4  42]
#  [193  61 115 100  56 170  90   7  94  56]
#  [ 24  27 101 159 249  35 105  45  22  36]
#  [ 11  99  58 172  41 103 208  26  12  97]
#  [ 31  28 210 183  86  26 107  63 113   3]
#  [  8 141  10 208  92   9 212  69  32 126]
#  [ 31 162  86  92 123  60  50 100   6  94]
#  [183 231 194 119 117 199 151  82  98  81]]
# [[159 238 217 115 255  59 191 173 127 239]
#  [191 167 218 253 255 246 122 191  28 247]
#  [235 254 247 237  63  63 244  55  87 255]
#  [253  61 119 111 184 171 223 215 254 255]
#  [155 251 119 255 249 119 255  47  31 181]
#  [207 243 190 253 189 239 249 186 174 233]
#  [127 188 251 191 246 250 239 191 119 235]
#  [201 175 190 244 223 127 247 237 180 255]
#  [159 183 254 127 255 189 186 245 174 223]
#  [183 231 230 247 255 207 183 243 255 221]]

# %%
img1 = cv2.imread(r"R8.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2 = cv2.imread(r"P.jpeg")
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
print(img1.shape)
print(img2.shape)

# resixe 10 x10
width = 10
height = 10 
dim = (width, height)
  
# resize image
imgR1 = cv2.resize(img1, dim)
imgR2 = cv2.resize(img2, dim)

XOR = cv2.bitwise_xor(imgR1, imgR2)

plt.imshow(imgR1, cmap='gray')
plt.show()
print(imgR1)
plt.imshow(imgR2, cmap='gray')
plt.show()
print(imgR2)
plt.imshow(OR, cmap='gray')
plt.show()
print(OR)
# Out:
# (8064, 6048)
# (509, 640)
# [[159   8  24  19  22  32  43  45 108 107]
#  [190  33  90  28  31  22  64  47  24 112]
#  [235  60   7 133  55  35 224  22  83 245]
#  [188  21  69 107 152 163 213 213 224 231]
#  [155 232  55 115  65 119 222   2  25 177]
#  [196 209 148 113 157 175 169 178 162 168]
#  [126 176 185 142 182 232 238 130 103 234]
#  [201 175 188 180 159 126 179 172 180 201]
#  [154 183 186 103 151 173 138 177 172 159]
#  [165 166 166 147 186 200 179 161 157 157]]
# [[148 230 201  97 237  59 158 165  19 197]
#  [131 135 130 245 229 228  58 149  12 183]
#  [107 230 242 108  46  30  20  35   4  42]
#  [193  61 115 100  56 170  90   7  94  56]
#  [ 24  27 101 159 249  35 105  45  22  36]
#  [ 11  99  58 172  41 103 208  26  12  97]
#  [ 31  28 210 183  86  26 107  63 113   3]
#  [  8 141  10 208  92   9 212  69  32 126]
#  [ 31 162  86  92 123  60  50 100   6  94]
#  [183 231 194 119 117 199 151  82  98  81]]
# [[159 238 217 115 255  59 191 173 127 239]
#  [191 167 218 253 255 246 122 191  28 247]
#  [235 254 247 237  63  63 244  55  87 255]
#  [253  61 119 111 184 171 223 215 254 255]
#  [155 251 119 255 249 119 255  47  31 181]
#  [207 243 190 253 189 239 249 186 174 233]
#  [127 188 251 191 246 250 239 191 119 235]
#  [201 175 190 244 223 127 247 237 180 255]
#  [159 183 254 127 255 189 186 245 174 223]
#  [183 231 230 247 255 207 183 243 255 221]]

# %%
img1 = cv2.imread(r"R8.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

NOT = cv2.bitwise_not(img1)

plt.imshow(img1)
plt.show()
plt.imshow(NOT)
plt.show()
